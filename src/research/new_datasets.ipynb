# %% [markdown]
# # New datasets

# %%
import sys
sys.path.append('../')
from tqdm.auto import tqdm
from loader import get_dataloader
from augmentations import get_composed_augmentations
import torch
from tqdm.notebook import tqdm
from torch.nn.functional import softmax
from utils import roc_btw_arr
import numpy as np

# %%
svhn_dl = get_dataloader({'dataset': 'SVHN_OOD', 
                           'split':'evaluation', 
                           'path': '../datasets', 
                           'batch_size': 64, 
                           'n_workers': 2, 
                           'shuffle':False,
                            'size':224})
# Out:
# Using No Augmentations
# Using No Augmentations
# Using downloaded and verified file: ../datasets/test_32x32.mat

# %%
a = svhn_dl.dataset[0][0]

# %%
a.shape
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# ## DTD

# %%
from torchvision.datasets import ImageFolder

# %%
ds = ImageFolder('../datasets/dtd/dtd/images/')

# %%
# ds.classes
ds.classes.index('sprinkled')
# Out:
# 36

# %%
l_class_images = np.nonzero(np.array(ds.targets) == 36)[0]
# ==18

# %%
from torchvision.utils import make_grid

# %%
img = [ds[idx][0] for idx in l_class_images]

# %%
# img[0]
img[11]
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %% [markdown]
# ## ImageNet-O

# %%
from torchvision.datasets import ImageFolder

# %%
ds = ImageFolder('../datasets/imagenet-o/imagenet-o')

# %%
ds.classes;

# %%
ds[-2][0]
# Out:
# <PIL.Image.Image image mode=RGB size=316x256>

# %% [markdown]
# ## OpenImages-O

# %%
openimages_dl = get_dataloader({'dataset': 'OpenImages-O', 
                           'split':'evaluation', 
                           'path': '../datasets', 
                           'batch_size': 64, 
                           'n_workers': 2, 
                           'shuffle':False,
                            'size':224})
# Out:
# Using No Augmentations
# Using No Augmentations

# %%
openimages_dl

# %%
a = openimages_dl.dataset

# %%
a[1][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
a[3][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(a[-5][0].permute(1,2,0))
